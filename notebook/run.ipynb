# %% [markdown]
# ### Connect gg drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/project/chat_with_data
# Out:
# /content/drive/MyDrive/project/chat_with_data

# %% [markdown]
# ### install lib

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Login hugging face for load model

# %%
from huggingface_hub import login
login(token = "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")

# %% [markdown]
# ### Run

# %%
from model import get_model
from main import build_rag_chain, Input, Output

llm = get_model(temparature = 0.8)
dir = "data"
genai_chain = build_rag_chain(llm, data_dir = dir, data_type="pdf")

# %% [markdown]
# ### Test

# %%
input = Input(question="What number president of the United States is Donald Trump?")
output = genai_chain.invoke(input.question)
print(output)
# Out:
# Donald Trump is the 47th President of the United States, and before that, he was the 45th President. He is not the 46th president. I don't know which number president he was before being the 45th president.
# Note: The answer provided is concise and within the three-sentence limit. It also clearly states that the user does not know which number president Donald Trump was before being the 45th president.

# %% [markdown]
# Kết luận llms đã truy xuất dữ liệu từ trong file pdf vì với mô hình llama 3 thì ko thể biết Trump là tổng thống thứ 47 được --> Done
